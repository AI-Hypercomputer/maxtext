# %% [markdown]
# https://orbax.readthedocs.io/en/latest/guides/checkpoint/debug_guide.html

# %%
import jax
import numpy as np
from etils import epath
import orbax.checkpoint as ocp
import tensorstore as ts
import collections
import operator
import asyncio
import re

# %% [markdown]
# ## inspect

# %%
def natural_sort_key(s: str):
    """
    Utility to sort parameter names, by splitting the string into text and number chunks.
    """
    return [int(text) if text.isdigit() else text for text in re.split(r'(\d+)', s)]


def inspect(path: str):
  """
  inspect orbax checkpoint by reading metadata
  """
  path = epath.Path(path)
  print(path)

  metadata = ocp.StandardCheckpointer().metadata(path)

  # 1 check size
  size_counts = collections.defaultdict(int)

  def get_arr_bytes(meta):
    dtype = meta.dtype
    shape = meta.shape
    size_counts[dtype] += 1
    return np.prod(shape) * np.dtype(dtype).itemsize

  total_bytes = jax.tree.reduce(operator.add, jax.tree.map(get_arr_bytes, metadata))
  print('{0:0.3f} GB'.format(float(total_bytes) / 1e9))
  print()


  # 2 check params only (skip opt_state): name and shape
  # k: name tuple, v: array meta data
  dictionary = ocp.tree.to_flat_dict(metadata)
  dictionary = {".".join(k): v.shape for k, v in dictionary.items() if k[0] == "params" }
  # sort layer name 1, 2 ...., 10 (rather than 1, 10, 2, ...)
  for k in sorted(dictionary, key=natural_sort_key):
      #print(f"{k}\n\t{dictionary[k]}")
      print(f"key | {k} | {dictionary[k]}")

  return metadata

# %%
  # print('leaf dtype counts:')
  # for dtype, count in size_counts.items():
  #   print(f'{dtype}: {count}')
  
  # # check parameter
  # metadata_contents = ['.'.join(k) for k in ocp.tree.to_flat_dict(metadata)]
  # # sort layer name 1, 2 ...., 10 (rather than 1, 10, 2, ...)
  # metadata_contents.sort(key=natural_sort_key)
  # # Here are the parameters present in the checkpoint tree.
  # for p in metadata_contents:
  #   # skip opt_state, params only
  #   if p.startswith("params"):
  #     print(p)
  # return metadata

# %% [markdown]
# ### Random

# %%
# metadata = inspect("/home/shuningjin/tmp/llama4/v5-scout-instruct-bf16-final-scanned/0/items")
metadata = inspect("/home/shuningjin/tmp/gcsfuse-jacobplatin/llama4/v5-scout-instruct-bf16-final-scanned/0/items")
# Out:
# /home/shuningjin/tmp/gcsfuse-jacobplatin/llama4/v5-scout-instruct-bf16-final-scanned/0/items
# 215.540 GB
#
# key | params.params.decoder.decoder_norm.scale | (5120,)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.MoeBlock_0.gate.kernel | (5120, 48, 16)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.MoeBlock_0.wi_0 | (16, 48, 5120, 8192)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.MoeBlock_0.wi_1 | (16, 48, 5120, 8192)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.MoeBlock_0.wo | (16, 48, 8192, 5120)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.shared_experts.wi_0.kernel | (5120, 48, 8192)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.shared_experts.wi_1.kernel | (5120, 48, 8192)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.shared_experts.wo.kernel | (8192, 48, 5120)
# key | params.params.decoder.layers.post_self_attention_layer_norm.scale | (5120, 48)
# key | params.params.decoder.layers.pre_self_attention_layer_norm.scale | (5120, 48)
# key | params.params.decoder.layers.self_attention.key.kernel | (5120, 48, 8, 128)
# key | params.params.decoder.layers.self_attention.out.kernel | (40, 48, 128, 5120)
# key | params.params.decoder.layers.self_attention.query.kernel | (5120, 48, 40, 128)
# key | params.params.decoder.layers.self_attention.value.kernel | (5120, 48, 8, 128)
# key | params.params.decoder.logits_dense.kernel | (5120, 202048)
# key | params.params.token_embedder.embedding | (202048, 5120)

# %%
dictionary = ocp.tree.to_flat_dict(metadata)
dictionary = {".".join(k): v for k, v in dictionary.items()}
dictionary["params.params.decoder.decoder_norm.scale"]
# Out:
# ArrayMetadata :  name=params.params.decoder.decoder_norm.scale,  directory=/home/shuningjin/tmp/gcsfuse-jacobplatin/llama4/v5-scout-instruct-bf16-final-scanned/0/items,  shape=(5120,),  sharding=NamedShardingMetadata(shape=[16], axis_names=['checkpoint_sharding_axis'], partition_spec=('checkpoint_sharding_axis',)) device_mesh=DeviceMetadataMesh(mesh=[DeviceMetadata(id=0), DeviceMetadata(id=1), DeviceMetadata(id=2), DeviceMetadata(id=3), DeviceMetadata(id=4), DeviceMetadata(id=5), DeviceMetadata(id=6), DeviceMetadata(id=7), DeviceMetadata(id=8), DeviceMetadata(id=9), DeviceMetadata(id=10), DeviceMetadata(id=11), DeviceMetadata(id=12), DeviceMetadata(id=13), DeviceMetadata(id=14), DeviceMetadata(id=15)]),  dtype=bfloat16,  storage=StorageMetadata(chunk_shape=(320,), write_shape=(320,)),

# %% [markdown]
# ### ckpt1

# %%
# jacob's ckpt from 4/15
# gs://jacobplatin/llama4/v5-scout-instruct-bf16-final-scanned/0/items
_ = inspect("/home/shuningjin/tmp/gcsfuse-jacobplatin/llama4/v5-scout-instruct-bf16-final-scanned/0/items")
# _ = inspect("/home/shuningjin/tmp/llama4/v5-scout-instruct-bf16-final-scanned/0/items")
# Out:
# /home/shuningjin/tmp/gcsfuse-jacobplatin/llama4/v5-scout-instruct-bf16-final-scanned/0/items
# 215.540 GB
#
# key | params.params.decoder.decoder_norm.scale | (5120,)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.MoeBlock_0.gate.kernel | (5120, 48, 16)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.MoeBlock_0.wi_0 | (16, 48, 5120, 8192)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.MoeBlock_0.wi_1 | (16, 48, 5120, 8192)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.MoeBlock_0.wo | (16, 48, 8192, 5120)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.shared_experts.wi_0.kernel | (5120, 48, 8192)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.shared_experts.wi_1.kernel | (5120, 48, 8192)
# key | params.params.decoder.layers.DeepSeekMoeBlock_0.shared_experts.wo.kernel | (8192, 48, 5120)
# key | params.params.decoder.layers.post_self_attention_layer_norm.scale | (5120, 48)
# key | params.params.decoder.layers.pre_self_attention_layer_norm.scale | (5120, 48)
# key | params.params.decoder.layers.self_attention.key.kernel | (5120, 48, 8, 128)
# key | params.params.decoder.layers.self_attention.out.kernel | (40, 48, 128, 5120)
# key | params.params.decoder.layers.self_attention.query.kernel | (5120, 48, 40, 128)
# key | params.params.decoder.layers.self_attention.value.kernel | (5120, 48, 8, 128)
# key | params.params.decoder.logits_dense.kernel | (5120, 202048)
# key | params.params.token_embedder.embedding | (202048, 5120)

# %% [markdown]
# ### ckpt2

# %%
# my newly generated ckpt with current conversion script
# gs://shuningjin-multipod-dev/llama4-17b-16e/conversion/meta-scanned/0/items
_ = inspect("/home/shuningjin/tmp/gcsfuse-shuningjin-multipod-dev/llama4-17b-16e/conversion/meta-scanned/0/items")
# Out:
# /home/shuningjin/tmp/gcsfuse-shuningjin-multipod-dev/llama4-17b-16e/conversion/meta-scanned/0/items
# 215.540 GB
#
# key | params.params.decoder.decoder_norm.scale | (5120,)
# key | params.params.decoder.layers.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 48, 16)
# key | params.params.decoder.layers.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 48, 5120, 8192)
# key | params.params.decoder.layers.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 48, 5120, 8192)
# key | params.params.decoder.layers.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 48, 8192, 5120)
# key | params.params.decoder.layers.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 48, 8192)
# key | params.params.decoder.layers.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 48, 8192)
# key | params.params.decoder.layers.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 48, 5120)
# key | params.params.decoder.layers.post_self_attention_layer_norm.scale | (5120, 48)
# key | params.params.decoder.layers.pre_self_attention_layer_norm.scale | (5120, 48)
# key | params.params.decoder.layers.self_attention.key.kernel | (5120, 48, 8, 128)
# key | params.params.decoder.layers.self_attention.out.kernel | (40, 48, 128, 5120)
# key | params.params.decoder.layers.self_attention.query.kernel | (5120, 48, 40, 128)
# key | params.params.decoder.layers.self_attention.value.kernel | (5120, 48, 8, 128)
# key | params.params.decoder.logits_dense.kernel | (5120, 202048)
# key | params.params.token_embedder.embedding | (202048, 5120)

# %% [markdown]
# ### ckpt3

# %%
# checkpoint from pretraing
# gs://shuningjin-multipod-dev/scout_pretrain/shuning-llama4-2025-06-22-23-49-54/checkpoints/0/items
_ = inspect("/home/shuningjin/tmp/gcsfuse-shuningjin-multipod-dev/scout_pretrain/shuning-llama4-2025-06-22-23-49-54/checkpoints/0/items")
# Out:
# /home/shuningjin/tmp/gcsfuse-shuningjin-multipod-dev/scout_pretrain/shuning-llama4-2025-06-22-23-49-54/checkpoints/0/items
# 646.619 GB
#
# key | params.params.decoder.decoder_norm.scale | (5120,)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 12, 16)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 12, 8192, 5120)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 12, 5120)
# key | params.params.decoder.layers.layers_0.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_0.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_0.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_0.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_0.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_0.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 12, 16)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 12, 8192, 5120)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 12, 5120)
# key | params.params.decoder.layers.layers_1.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_1.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_1.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_1.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_1.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_1.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 12, 16)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 12, 8192, 5120)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 12, 5120)
# key | params.params.decoder.layers.layers_2.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_2.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_2.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_2.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_2.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_2.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 12, 16)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 12, 8192, 5120)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 12, 5120)
# key | params.params.decoder.layers.layers_3.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_3.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_3.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_3.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_3.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_3.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.logits_dense.kernel | (5120, 202048)
# key | params.params.token_embedder.embedding | (202048, 5120)

# %% [markdown]
# ### ckpt 4 (scout new pretrain)

# %%
# gs://shuningjin-multipod-dev/scout_pretrain/shuning-llama4-2025-06-29-06-11-10/checkpoints/0/items
_ = inspect("/home/shuningjin/tmp/gcsfuse-shuningjin-multipod-dev/scout_pretrain/shuning-llama4-2025-06-29-06-11-10/checkpoints/0/items")
# Out:
# /home/shuningjin/tmp/gcsfuse-shuningjin-multipod-dev/scout_pretrain/shuning-llama4-2025-06-29-06-11-10/checkpoints/0/items
# 646.619 GB
#
# key | params.params.decoder.decoder_norm.scale | (5120,)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 12, 16)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 12, 8192, 5120)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_0.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 12, 5120)
# key | params.params.decoder.layers.layers_0.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_0.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_0.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_0.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_0.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_0.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 12, 16)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 12, 8192, 5120)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 12, 5120)
# key | params.params.decoder.layers.layers_1.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_1.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_1.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_1.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_1.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_1.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 12, 16)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 12, 8192, 5120)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_2.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 12, 5120)
# key | params.params.decoder.layers.layers_2.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_2.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_2.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_2.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_2.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_2.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 12, 16)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 12, 8192, 5120)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 12, 5120)
# key | params.params.decoder.layers.layers_3.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_3.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_3.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_3.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_3.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_3.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.logits_dense.kernel | (5120, 202048)
# key | params.params.token_embedder.embedding | (202048, 5120)

# %% [markdown]
# ### ckpt 5 (maverick new pretrain)

# %%
# gs://shuningjin-multipod-dev/maverick_pretrain/shuning-llama4-2025-06-29-11-38-39/checkpoints/0/items
inspect("/home/shuningjin/tmp/gcsfuse-shuningjin-multipod-dev/maverick_pretrain/shuning-llama4-2025-06-29-11-38-39/checkpoints/0/items")
# Out:
# /home/shuningjin/tmp/gcsfuse-shuningjin-multipod-dev/maverick_pretrain/shuning-llama4-2025-06-29-11-38-39/checkpoints/0/items
# 2404.271 GB
#
# key | params.params.decoder.decoder_norm.scale | (5120,)
# key | params.params.decoder.layers.layers_0.mlp.wi_0.kernel | (5120, 12, 16384)
# key | params.params.decoder.layers.layers_0.mlp.wi_1.kernel | (5120, 12, 16384)
# key | params.params.decoder.layers.layers_0.mlp.wo.kernel | (16384, 12, 5120)
# key | params.params.decoder.layers.layers_0.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_0.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_0.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_0.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_0.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_0.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 12, 128)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (128, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (128, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.MoeBlock_0.wo | (128, 12, 8192, 5120)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_1.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 12, 5120)
# key | params.params.decoder.layers.layers_1.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_1.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_1.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_1.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_1.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_1.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_2.mlp.wi_0.kernel | (5120, 12, 16384)
# key | params.params.decoder.layers.layers_2.mlp.wi_1.kernel | (5120, 12, 16384)
# key | params.params.decoder.layers.layers_2.mlp.wo.kernel | (16384, 12, 5120)
# key | params.params.decoder.layers.layers_2.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_2.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_2.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_2.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_2.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_2.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 12, 128)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (128, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (128, 12, 5120, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.MoeBlock_0.wo | (128, 12, 8192, 5120)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 12, 8192)
# key | params.params.decoder.layers.layers_3.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 12, 5120)
# key | params.params.decoder.layers.layers_3.post_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_3.pre_self_attention_layer_norm.scale | (5120, 12)
# key | params.params.decoder.layers.layers_3.self_attention.key.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.layers.layers_3.self_attention.out.kernel | (40, 12, 128, 5120)
# key | params.params.decoder.layers.layers_3.self_attention.query.kernel | (5120, 12, 40, 128)
# key | params.params.decoder.layers.layers_3.self_attention.value.kernel | (5120, 12, 8, 128)
# key | params.params.decoder.logits_dense.kernel | (5120, 202048)
# key | params.params.token_embedder.embedding | (202048, 5120)
# TreeMetadata(
#   custom_metadata=None
#   tree={'opt_state': [{'count': ArrayMetadata :  name=opt_state.0.count,  directory=/home/shuningjin/tmp/gcsfuse-shuningjin-multipod-dev/maverick_pretrain/shuning-llama4-2025-06-29-11-38-39/checkpoints/0/items,  shape=(),  sharding=NamedShardingMetadata(shape=[  1   1 256   1   1   1   1   1   1   1   1   1], axis_names=['data', 'stage', 'fsdp', 'fsdp_transpose', 'sequence', 'context', 'context_autoregressive', 'tensor', 'tensor_transpose', 'tensor_sequence', 'expert', 'autoregressive'], partition_spec=()) device_mesh=DeviceMetadataMesh(mesh=[[[[[[[[[[[[DeviceMetadata(id=100000)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100032)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100064)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100096)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100128)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100160)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100192)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100224)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100004)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100036)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100068)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100100)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100132)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100164)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100196)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100228)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100008)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100040)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100072)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100104)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100136)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100168)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100200)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100232)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100012)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100044)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100076)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100108)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100140)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100172)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100204)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100236)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100016)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100048)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100080)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100112)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100144)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100176)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100208)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100240)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100020)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100052)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100084)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100116)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100148)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100180)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100212)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100244)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100024)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100056)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100088)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100120)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100152)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100184)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100216)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100248)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100028)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100060)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100092)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100124)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100156)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100188)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100220)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100252)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100001)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100033)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100065)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100097)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100129)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100161)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100193)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100225)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100005)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100037)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100069)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=100101)]]]]]]]]], [[[[[[[[[DeviceMetadata(id=10 ...
# )

# %% [markdown]
# ### unscanned

# %%
# from xlml test: http://shortn/_dILntrz9GX
# gs://maxtext-llama/llama4-17b-16e/2025-06-27/unscanned
_ = inspect("/home/shuningjin/tmp/gcsfuse-maxtext-llama/llama4-17b-16e/2025-06-27/unscanned/0/items")
# Out:
# /home/shuningjin/tmp/gcsfuse-maxtext-llama/llama4-17b-16e/2025-06-27/unscanned/0/items
# 215.540 GB
#
# key | params.params.decoder.decoder_norm.scale | (5120,)
# key | params.params.decoder.layers_0.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_0.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_0.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_0.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_0.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_0.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_0.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_0.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_0.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_0.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_0.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_0.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_0.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_1.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_1.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_1.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_1.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_1.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_1.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_1.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_1.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_1.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_1.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_1.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_1.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_1.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_2.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_2.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_2.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_2.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_2.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_2.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_2.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_2.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_2.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_2.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_2.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_2.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_2.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_3.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_3.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_3.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_3.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_3.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_3.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_3.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_3.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_3.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_3.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_3.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_3.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_3.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_4.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_4.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_4.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_4.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_4.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_4.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_4.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_4.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_4.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_4.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_4.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_4.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_4.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_5.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_5.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_5.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_5.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_5.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_5.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_5.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_5.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_5.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_5.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_5.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_5.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_5.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_6.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_6.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_6.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_6.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_6.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_6.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_6.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_6.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_6.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_6.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_6.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_6.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_6.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_7.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_7.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_7.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_7.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_7.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_7.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_7.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_7.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_7.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_7.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_7.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_7.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_7.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_8.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_8.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_8.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_8.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_8.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_8.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_8.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_8.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_8.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_8.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_8.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_8.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_8.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_9.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_9.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_9.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_9.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_9.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_9.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_9.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_9.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_9.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_9.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_9.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_9.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_9.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_10.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_10.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_10.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_10.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_10.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_10.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_10.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_10.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_10.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_10.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_10.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_10.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_10.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_11.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_11.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_11.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_11.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_11.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_11.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_11.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_11.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_11.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_11.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_11.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_11.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_11.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_12.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_12.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_12.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_12.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_12.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_12.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_12.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_12.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_12.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_12.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_12.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_12.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_12.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_13.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_13.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_13.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_13.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_13.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_13.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_13.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_13.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_13.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_13.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_13.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_13.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_13.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_14.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_14.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_14.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_14.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_14.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_14.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_14.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_14.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_14.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_14.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_14.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_14.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_14.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_15.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_15.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_15.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_15.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_15.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_15.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_15.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_15.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_15.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_15.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_15.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_15.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_15.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_16.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_16.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_16.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_16.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_16.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_16.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_16.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_16.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_16.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_16.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_16.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_16.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_16.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_17.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_17.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_17.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_17.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_17.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_17.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_17.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_17.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_17.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_17.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_17.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_17.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_17.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_18.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_18.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_18.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_18.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_18.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_18.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_18.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_18.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_18.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_18.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_18.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_18.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_18.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_19.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_19.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_19.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_19.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_19.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_19.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_19.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_19.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_19.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_19.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_19.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_19.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_19.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_20.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_20.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_20.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_20.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_20.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_20.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_20.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_20.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_20.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_20.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_20.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_20.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_20.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_21.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_21.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_21.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_21.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_21.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_21.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_21.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_21.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_21.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_21.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_21.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_21.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_21.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_22.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_22.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_22.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_22.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_22.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_22.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_22.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_22.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_22.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_22.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_22.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_22.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_22.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_23.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_23.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_23.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_23.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_23.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_23.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_23.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_23.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_23.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_23.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_23.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_23.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_23.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_24.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_24.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_24.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_24.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_24.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_24.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_24.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_24.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_24.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_24.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_24.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_24.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_24.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_25.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_25.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_25.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_25.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_25.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_25.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_25.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_25.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_25.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_25.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_25.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_25.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_25.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_26.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_26.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_26.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_26.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_26.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_26.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_26.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_26.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_26.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_26.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_26.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_26.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_26.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_27.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_27.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_27.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_27.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_27.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_27.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_27.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_27.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_27.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_27.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_27.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_27.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_27.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_28.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_28.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_28.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_28.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_28.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_28.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_28.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_28.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_28.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_28.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_28.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_28.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_28.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_29.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_29.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_29.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_29.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_29.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_29.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_29.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_29.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_29.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_29.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_29.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_29.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_29.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_30.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_30.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_30.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_30.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_30.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_30.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_30.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_30.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_30.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_30.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_30.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_30.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_30.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_31.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_31.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_31.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_31.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_31.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_31.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_31.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_31.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_31.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_31.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_31.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_31.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_31.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_32.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_32.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_32.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_32.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_32.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_32.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_32.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_32.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_32.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_32.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_32.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_32.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_32.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_33.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_33.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_33.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_33.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_33.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_33.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_33.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_33.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_33.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_33.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_33.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_33.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_33.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_34.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_34.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_34.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_34.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_34.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_34.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_34.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_34.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_34.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_34.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_34.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_34.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_34.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_35.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_35.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_35.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_35.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_35.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_35.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_35.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_35.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_35.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_35.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_35.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_35.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_35.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_36.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_36.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_36.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_36.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_36.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_36.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_36.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_36.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_36.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_36.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_36.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_36.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_36.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_37.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_37.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_37.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_37.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_37.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_37.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_37.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_37.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_37.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_37.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_37.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_37.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_37.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_38.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_38.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_38.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_38.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_38.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_38.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_38.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_38.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_38.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_38.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_38.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_38.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_38.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_39.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_39.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_39.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_39.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_39.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_39.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_39.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_39.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_39.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_39.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_39.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_39.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_39.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_40.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_40.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_40.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_40.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_40.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_40.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_40.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_40.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_40.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_40.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_40.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_40.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_40.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_41.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_41.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_41.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_41.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_41.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_41.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_41.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_41.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_41.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_41.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_41.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_41.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_41.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_42.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_42.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_42.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_42.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_42.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_42.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_42.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_42.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_42.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_42.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_42.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_42.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_42.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_43.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_43.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_43.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_43.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_43.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_43.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_43.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_43.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_43.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_43.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_43.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_43.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_43.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_44.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_44.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_44.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_44.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_44.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_44.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_44.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_44.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_44.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_44.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_44.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_44.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_44.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_45.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_45.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_45.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_45.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_45.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_45.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_45.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_45.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_45.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_45.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_45.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_45.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_45.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_46.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_46.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_46.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_46.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_46.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_46.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_46.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_46.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_46.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_46.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_46.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_46.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_46.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_47.Llama4MoEBlock_0.MoeBlock_0.gate.kernel | (5120, 16)
# key | params.params.decoder.layers_47.Llama4MoEBlock_0.MoeBlock_0.wi_0 | (16, 5120, 8192)
# key | params.params.decoder.layers_47.Llama4MoEBlock_0.MoeBlock_0.wi_1 | (16, 5120, 8192)
# key | params.params.decoder.layers_47.Llama4MoEBlock_0.MoeBlock_0.wo | (16, 8192, 5120)
# key | params.params.decoder.layers_47.Llama4MoEBlock_0.shared_experts.wi_0.kernel | (5120, 8192)
# key | params.params.decoder.layers_47.Llama4MoEBlock_0.shared_experts.wi_1.kernel | (5120, 8192)
# key | params.params.decoder.layers_47.Llama4MoEBlock_0.shared_experts.wo.kernel | (8192, 5120)
# key | params.params.decoder.layers_47.post_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_47.pre_self_attention_layer_norm.scale | (5120,)
# key | params.params.decoder.layers_47.self_attention.key.kernel | (5120, 8, 128)
# key | params.params.decoder.layers_47.self_attention.out.kernel | (40, 128, 5120)
# key | params.params.decoder.layers_47.self_attention.query.kernel | (5120, 40, 128)
# key | params.params.decoder.layers_47.self_attention.value.kernel | (5120, 8, 128)
# key | params.params.decoder.logits_dense.kernel | (5120, 202048)
# key | params.params.token_embedder.embedding | (202048, 5120)

# %% [markdown]
# ## Mixtral

# %%
# gs://ml-auto-solutions/output/sparsity_diffusion_devx/maxtext/chained_tests_mixtral-8x7b_nightly-2024-11-15-01-06-09/unscanned_ckpt/checkpoints/0/items
# bash setup_gcsfuse.sh DATASET_GCS_BUCKET=ml-auto-solutions MOUNT_PATH=/home/shuningjin/tmp/gcsfuse-ml-auto-solutions
inspect("/home/shuningjin/tmp/gcsfuse-ml-auto-solutions/output/sparsity_diffusion_devx/maxtext/chained_tests_mixtral-8x7b_nightly-2024-11-15-01-06-09/unscanned_ckpt/checkpoints/0/items")
# Out:
# /home/shuningjin/tmp/gcsfuse-ml-auto-solutions/output/sparsity_diffusion_devx/maxtext/chained_tests_mixtral-8x7b_nightly-2024-11-15-01-06-09/unscanned_ckpt/checkpoints/0/items
# 93.406 GB
#
# key | params.params.decoder.decoder_norm.scale | (4096,)
# key | params.params.decoder.layers_0.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_0.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_0.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_0.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_0.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_0.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_0.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_0.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_0.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_0.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_1.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_1.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_1.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_1.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_1.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_1.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_1.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_1.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_1.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_1.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_2.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_2.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_2.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_2.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_2.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_2.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_2.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_2.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_2.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_2.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_3.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_3.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_3.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_3.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_3.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_3.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_3.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_3.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_3.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_3.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_4.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_4.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_4.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_4.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_4.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_4.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_4.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_4.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_4.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_4.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_5.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_5.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_5.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_5.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_5.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_5.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_5.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_5.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_5.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_5.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_6.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_6.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_6.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_6.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_6.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_6.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_6.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_6.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_6.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_6.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_7.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_7.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_7.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_7.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_7.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_7.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_7.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_7.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_7.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_7.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_8.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_8.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_8.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_8.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_8.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_8.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_8.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_8.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_8.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_8.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_9.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_9.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_9.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_9.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_9.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_9.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_9.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_9.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_9.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_9.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_10.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_10.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_10.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_10.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_10.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_10.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_10.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_10.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_10.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_10.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_11.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_11.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_11.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_11.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_11.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_11.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_11.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_11.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_11.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_11.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_12.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_12.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_12.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_12.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_12.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_12.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_12.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_12.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_12.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_12.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_13.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_13.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_13.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_13.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_13.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_13.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_13.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_13.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_13.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_13.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_14.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_14.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_14.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_14.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_14.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_14.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_14.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_14.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_14.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_14.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_15.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_15.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_15.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_15.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_15.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_15.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_15.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_15.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_15.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_15.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_16.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_16.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_16.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_16.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_16.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_16.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_16.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_16.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_16.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_16.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_17.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_17.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_17.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_17.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_17.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_17.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_17.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_17.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_17.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_17.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_18.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_18.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_18.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_18.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_18.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_18.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_18.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_18.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_18.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_18.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_19.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_19.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_19.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_19.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_19.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_19.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_19.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_19.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_19.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_19.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_20.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_20.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_20.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_20.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_20.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_20.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_20.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_20.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_20.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_20.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_21.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_21.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_21.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_21.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_21.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_21.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_21.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_21.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_21.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_21.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_22.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_22.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_22.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_22.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_22.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_22.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_22.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_22.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_22.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_22.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_23.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_23.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_23.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_23.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_23.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_23.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_23.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_23.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_23.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_23.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_24.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_24.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_24.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_24.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_24.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_24.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_24.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_24.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_24.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_24.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_25.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_25.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_25.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_25.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_25.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_25.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_25.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_25.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_25.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_25.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_26.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_26.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_26.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_26.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_26.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_26.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_26.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_26.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_26.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_26.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_27.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_27.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_27.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_27.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_27.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_27.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_27.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_27.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_27.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_27.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_28.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_28.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_28.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_28.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_28.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_28.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_28.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_28.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_28.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_28.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_29.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_29.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_29.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_29.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_29.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_29.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_29.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_29.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_29.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_29.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_30.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_30.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_30.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_30.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_30.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_30.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_30.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_30.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_30.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_30.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_31.MoeBlock_0.gate.kernel | (4096, 8)
# key | params.params.decoder.layers_31.MoeBlock_0.wi_0 | (8, 4096, 14336)
# key | params.params.decoder.layers_31.MoeBlock_0.wi_1 | (8, 4096, 14336)
# key | params.params.decoder.layers_31.MoeBlock_0.wo | (8, 14336, 4096)
# key | params.params.decoder.layers_31.post_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_31.pre_self_attention_layer_norm.scale | (4096,)
# key | params.params.decoder.layers_31.self_attention.key.kernel | (4096, 8, 128)
# key | params.params.decoder.layers_31.self_attention.out.kernel | (32, 128, 4096)
# key | params.params.decoder.layers_31.self_attention.query.kernel | (4096, 32, 128)
# key | params.params.decoder.layers_31.self_attention.value.kernel | (4096, 8, 128)
# key | params.params.decoder.logits_dense.kernel | (4096, 32000)
# key | params.params.token_embedder.embedding | (32000, 4096)
# TreeMetadata(
#   custom_metadata=None
#   tree={'opt_state': {}, 'params': {'params': {'decoder': {'decoder_norm': {'scale': ArrayMetadata :  name=params.params.decoder.decoder_norm.scale,  directory=/home/shuningjin/tmp/gcsfuse-ml-auto-solutions/output/sparsity_diffusion_devx/maxtext/chained_tests_mixtral-8x7b_nightly-2024-11-15-01-06-09/unscanned_ckpt/checkpoints/0/items,  shape=(4096,),  sharding=NamedShardingMetadata(shape=[1 1 1 1 1 1 1 1], axis_names=['data', 'stage', 'fsdp', 'fsdp_transpose', 'sequence', 'tensor', 'expert', 'autoregressive'], partition_spec=('tensor',)) device_mesh=DeviceMetadataMesh(mesh=[[[[[[[[DeviceMetadata(id=0)]]]]]]]]),  dtype=bfloat16,  storage=StorageMetadata(chunk_shape=(4096,), write_shape=None),}, 'layers_0': {'MoeBlock_0': {'gate': {'kernel': ArrayMetadata :  name=params.params.decoder.layers_0.MoeBlock_0.gate.kernel,  directory=/home/shuningjin/tmp/gcsfuse-ml-auto-solutions/output/sparsity_diffusion_devx/maxtext/chained_tests_mixtral-8x7b_nightly-2024-11-15-01-06-09/unscanned_ckpt/checkpoints/0/items,  shape=(4096, 8),  sharding=NamedShardingMetadata(shape=[1 1 1 1 1 1 1 1], axis_names=['data', 'stage', 'fsdp', 'fsdp_transpose', 'sequence', 'tensor', 'expert', 'autoregressive'], partition_spec=(['fsdp', 'sequence', 'expert'], ['fsdp_transpose', 'tensor', 'autoregressive'])) device_mesh=DeviceMetadataMesh(mesh=[[[[[[[[DeviceMetadata(id=0)]]]]]]]]),  dtype=bfloat16,  storage=StorageMetadata(chunk_shape=(4096, 8), write_shape=None),}, 'wi_0': ArrayMetadata :  name=params.params.decoder.layers_0.MoeBlock_0.wi_0,  directory=/home/shuningjin/tmp/gcsfuse-ml-auto-solutions/output/sparsity_diffusion_devx/maxtext/chained_tests_mixtral-8x7b_nightly-2024-11-15-01-06-09/unscanned_ckpt/checkpoints/0/items,  shape=(8, 4096, 14336),  sharding=NamedShardingMetadata(shape=[1 1 1 1 1 1 1 1], axis_names=['data', 'stage', 'fsdp', 'fsdp_transpose', 'sequence', 'tensor', 'expert', 'autoregressive'], partition_spec=('expert', ['fsdp', 'sequence'], ['fsdp_transpose', 'tensor', 'autoregressive'])) device_mesh=DeviceMetadataMesh(mesh=[[[[[[[[DeviceMetadata(id=0)]]]]]]]]),  dtype=bfloat16,  storage=StorageMetadata(chunk_shape=(8, 4096, 14336), write_shape=None),, 'wi_1': ArrayMetadata :  name=params.params.decoder.layers_0.MoeBlock_0.wi_1,  directory=/home/shuningjin/tmp/gcsfuse-ml-auto-solutions/output/sparsity_diffusion_devx/maxtext/chained_tests_mixtral-8x7b_nightly-2024-11-15-01-06-09/unscanned_ckpt/checkpoints/0/items,  shape=(8, 4096, 14336),  sharding=NamedShardingMetadata(shape=[1 1 1 1 1 1 1 1], axis_names=['data', 'stage', 'fsdp', 'fsdp_transpose', 'sequence', 'tensor', 'expert', 'autoregressive'], partition_spec=('expert', ['fsdp', 'sequence'], ['fsdp_transpose', 'tensor', 'autoregressive'])) device_mesh=DeviceMetadataMesh(mesh=[[[[[[[[DeviceMetadata(id=0)]]]]]]]]),  dtype=bfloat16,  storage=StorageMetadata(chunk_shape=(8, 4096, 14336), write_shape=None),, 'wo': ArrayMetadata :  name=params.params.decoder.layers_0.MoeBlock_0.wo,  directory=/home/shuningjin/tmp/gcsfuse-ml-auto-solutions/output/sparsity_diffusion_devx/maxtext/chained_tests_mixtral-8x7b_nightly-2024-11-15-01-06-09/unscanned_ckpt/checkpoints/0/items,  shape=(8, 14336, 4096),  sharding=NamedShardingMetadata(shape=[1 1 1 1 1 1 1 1], axis_names=['data', 'stage', 'fsdp', 'fsdp_transpose', 'sequence', 'tensor', 'expert', 'autoregressive'], partition_spec=('expert', ['fsdp_transpose', 'tensor', 'autoregressive'], ['fsdp', 'sequence'])) device_mesh=DeviceMetadataMesh(mesh=[[[[[[[[DeviceMetadata(id=0)]]]]]]]]),  dtype=bfloat16,  storage=StorageMetadata(chunk_shape=(8, 14336, 4096), write_shape=None),}, 'post_self_attention_layer_norm': {'scale': ArrayMetadata :  name=params.params.decoder.layers_0.post_self_attention_layer_norm.scale,  directory=/home/shuningjin/tmp/gcsfuse-ml-auto-solutions/output/sparsity_diffusion_devx/maxtext/chained_tests_mixtral-8x7b_nightly-2024-11-15-01-06-09/unscanned_ckpt/checkpoints/0/items,  shape=(4096,),  sharding=NamedShardingMetadata(shape=[1 1 1 1 1 1 1 1], ...
# )

# %% [markdown]
# ## other

# %%
state = {
    'a': {
        'x': np.arange(2 ** 24),
        'y': np.arange(1024),
    },
    'b': np.ones(8),
    'c': 42,
}

default_param_name = 'a.x'
default_path = epath.Path('/home/shuningjin/tmp/sample_checkpoint')
if default_path.exists():
  default_path.rmtree()
with ocp.StandardCheckpointer() as ckptr:
  ckptr.save(default_path, state)


# gs://jacobplatin/llama4/v5-scout-instruct-bf16-final-scanned/0/items
PATH="/home/shuningjin/tmp/llama4//v5-scout-instruct-bf16-final-scanned/0/items"
path = epath.Path(PATH)
print(path)


metadata = ocp.StandardCheckpointer().metadata(path)
size_counts = collections.defaultdict(int)

def get_arr_bytes(meta):
  dtype = meta.dtype
  shape = meta.shape
  size_counts[dtype] += 1
  return np.prod(shape) * np.dtype(dtype).itemsize

total_bytes = jax.tree.reduce(operator.add, jax.tree.map(get_arr_bytes, metadata))
print('{0:0.3f} GB'.format(float(total_bytes) / 1e9))
print()
print('leaf dtype counts:')
for dtype, count in size_counts.items():
  print(f'{dtype}: {count}')


metadata = ocp.StandardCheckpointer().metadata(path)
metadata_contents = ['.'.join(k) for k in ocp.tree.to_flat_dict(metadata)]
# Here are the parameters present in the checkpoint tree.
for p in metadata_contents:
  print(p)
# Out:
# /home/shuningjin/tmp/llama4/v5-scout-instruct-bf16-final-scanned/0/items
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 24
#      20 path = epath.Path(PATH)
#      21 print(path)
# ---> 24 metadata = ocp.StandardCheckpointer().metadata(path)
#      25 size_counts = collections.defaultdict(int)
#      27 def get_arr_bytes(meta):
#
# File ~/venv-maxtext/lib/python3.10/site-packages/orbax/checkpoint/_src/checkpointers/checkpointer.py:328, in Checkpointer.metadata(self, directory)
#     326 """See superclass documentation."""
#     327 directory = epath.Path(directory)
# --> 328 return self._handler.metadata(directory)
#
# File ~/venv-maxtext/lib/python3.10/site-packages/orbax/checkpoint/_src/handlers/standard_checkpoint_handler.py:268, in StandardCheckpointHandler.metadata(self, directory)
#     266 def metadata(self, directory: epath.Path) -> tree_metadata.TreeMetadata:
#     267   """Returns metadata about the saved item."""
# --> 268   return self._impl.metadata(directory)
#
# File ~/venv-maxtext/lib/python3.10/site-packages/orbax/checkpoint/_src/handlers/pytree_checkpoint_handler.py:1045, in PyTreeCheckpointHandler.metadata(self, directory)
#    1019 def metadata(self, directory: epath.Path) -> tree_metadata.TreeMetadata:
#    1020   """Returns tree metadata.
#    1021
#    1022   The result will be a PyTree matching the structure of the saved checkpoint.
#    (...)
#    1043     tree containing metadata.
#    1044   """
# -> 1045   return self._handler_impl.metadata(directory)
#
# File ~/venv-maxtext/lib/python3.10/site-packages/orbax/checkpoint/_src/handlers/base_pytree_checkpoint_handler.py:1037, in BasePyTreeCheckpointHandler.metadata(self, directory)
#    1011 """Returns tree metadata.
#    1012
#    1013 The result will be a PyTree matching the structure of the saved checkpoint.
#    (...)
#    1034   tree containing metadata.
#    1035 """
#    1036 is_ocdbt_checkpoint = type_handlers.is_ocdbt_checkpoint(directory)
# -> 1037 internal_tree_metadata = self._read_metadata_file(directory)
#    1038 return tree_metadata.build_default_tree_metadata(
#    1039     internal_tree_metadata.as_custom_metadata(
#    1040         directory,
#    (...)
#    1044     custom_metadata=internal_tree_metadata.custom_metadata,
#    1045 )
#
# File ~/venv-maxtext/lib/python3.10/site-packages/orbax/checkpoint/_src/handlers/base_pytree_checkpoint_handler.py:994, in BasePyTreeCheckpointHandler._read_metadata_file(self, directory)
#     992 path = directory / PYTREE_METADATA_FILE
#     993 if not path.exists():
# --> 994   raise FileNotFoundError(
#     995       f'Metadata file (named {PYTREE_METADATA_FILE}) does not exist at'
#     996       f' {directory}.'
#     997   )
#     998 logging.vlog(
#     999     1,
#    1000     'Reading pytree metadata file: %s with pytree_metadata_options: %s',
#    1001     path,
#    1002     self._pytree_metadata_options,
#    1003 )
#    1004 return tree_metadata.InternalTreeMetadata.from_json(
#    1005     json.loads(path.read_text()),
#    1006     pytree_metadata_options=self._pytree_metadata_options,
#    1007 )
#
# FileNotFoundError: Metadata file (named _METADATA) does not exist at /home/shuningjin/tmp/llama4/v5-scout-instruct-bf16-final-scanned/0/items.

# %%
async def disk_usage(path: epath.Path) -> int:
  """Returns the size of the checkpoint on disk.

  Note: this uses recurision because Orbax checkpoint directories are never
  more than a few levels deep.

  Args:
    path: The path to the checkpoint.
  Returns:
    The size of the checkpoint on disk.
  """

  async def helper(p):
    if p.is_dir():
      return await disk_usage(p)
    else:
      stat = await ocp.path.async_utils.async_stat(path)
      return stat.length

  futures = []
  for p in path.iterdir():
    futures.append(helper(p))
  return sum(await asyncio.gather(*futures))

print('{0:0.3f} GB'.format(float(asyncio.run(disk_usage(path))) / 1e9))

# %%
# Note: instead of "file", use:
#   - "gfile" on Google-internal filesystems.
#   - "gs" on GCS (do not repeat the "gs://" prefix)
ts_contents = ts.KvStore.open({"driver": "ocdbt", "base": f"file://{path.as_posix()}"}).result().list().result()
ts_contents = [p.decode("utf-8") for p in ts_contents]
ts_contents = [p.replace('.zarray', '')[:-1] for p in ts_contents if '.zarray' in p]

# We can assert that the parameters tracked by the metadata file are
# the same as those tracked by Tensorstore. If there is a discrepancy, there may
# be a deeper underlying problem.

assert len(metadata_contents) == len(ts_contents) and sorted(metadata_contents) == sorted(ts_contents)

# %%
path = ""  # @param {type:"string"}
# The `param_name` can be obtained by inspecting tree metadata (see above).
param_name = ""  # @param {type:"string"}
path = default_path or epath.Path(path)
param_name = default_param_name or param_name

# %%
metadata = ocp.StandardCheckpointer().metadata(path)
value_metadata = {'.'.join(k): v for k, v in ocp.tree.to_flat_dict(metadata).items()}[param_name]

# %%
print(f'shape: {value_metadata.shape}')
print(f'dtype: {value_metadata.dtype}')

# %%
ParamInfo = ocp.type_handlers.ParamInfo
ts_context = ts.Context({
    'file_io_concurrency': {'limit': 128},
    'cache_pool#ocdbt': {'total_bytes_limit': 100000000},
})

info = ParamInfo(name=param_name, path=path / param_name, parent_dir=path, is_ocdbt_checkpoint=True, use_zarr3=False)
tspec = ocp.type_handlers.get_json_tspec_read(info, use_ocdbt=True)

t = ts.open(ts.Spec(tspec), open=True, context=ts_context).result()
arr = t.read().result()
print(arr)

# %%
import numpy as np
np.zeros((8,) + (4,3)).shape
# Out:
# (8, 4, 3)
